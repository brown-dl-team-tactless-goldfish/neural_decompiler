# %%
import sys
sys.path.append('content')


from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Unzipping data

# %%
{
    "tags": [
        "hide-output"
    ]
}
# !unzip /content/gdrive/My\ Drive/dl_project/dl_final_project/data/leetcode_data_FINAL.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/subtree-of-another-tree-12.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/reach-a-number-1.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/print-in-order-4.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/element-appearing-more-than-25-in-sorted-array-1.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/super-ugly-number-1.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/evaluate-reverse-polish-notation-11.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/corporate-flight-bookings-1.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/reach-a-number-11.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/delete-nodes-and-return-forest-0.txt
#   inflating: leetcode_data_FINAL/C_COMPILED_FILES/disconnect-path-in-a-binary-matrix-by-at-most-one-flip-0.txt
# ...

# %% [markdown]
# Import neural_decompiler.py

# %%
# !python /content/gdrive/My\ Drive/dl_project/dl_final_project/model/neural_decompiler.py
# Out:
# 2023-05-04 01:03:10.560684: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 01:03:11.579403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# loading data . . .
# ASM file: ASM_zuma-game-6.txt | C file: zuma-game-6.txt
# 2023-05-04 01:03:35.748420: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
